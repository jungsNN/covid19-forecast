# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('precision', 4)

# %%
cdc = pd.read_csv("2020-08-24-all-forecasted-cases-model-data.csv")
cdc.info()
cdc.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206173 entries, 0 to 206172
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   model            206173 non-null  object
#  1   forecast_date    206173 non-null  object
#  2   target           206173 non-null  object
#  3   target_end_date  206173 non-null  object
#  4   location_name    206173 non-null  object
#  5   State            206173 non-null  object
#  6   fips             206173 non-null  object
#  7   point            206173 non-null  int64
#  8   quantile_0.025   172701 non-null  float64
#  9   quantile_0.25    172701 non-null  float64
#  10  quantile_0.75    172701 non-null  float64
#  11  quantile_0.975   172537 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 18.9+ MB
#       model forecast_date               target target_end_date location_name  \
# ...

# %% [markdown]
# Strategy:
# * Group by state and aggregate mean for continuous values (predictions)
# * use the actual weekly case increase data (load from another source) as y
# * use the errors, y - yhat, to measure how close or far the predictions were
# * then implement the weights to train a model to approximate future cases
